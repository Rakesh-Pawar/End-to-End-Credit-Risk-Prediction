# %% [markdown]
# # <center> End-to-End Project- Credit Risk

# %% [markdown]
# ### Task- 2

# %% [markdown]
# ### Develop the ML model(s) to predict the credit risk(low or high) for a given applicant.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np                                                        # For pre-preocessing data
import pandas as pd                                                       # For pre-preocessing data
import matplotlib.pyplot as plt                                           # For visualisation
# %matplotlib inline
import seaborn as sns                                                     # For visualisation

pd.set_option('display.max_rows', 250)                                    # to show upto 250 rows in output
pd.set_option('display.max_colwidth',250)                                 # to show upto 250 cols in output
pd.set_option('display.float_format', lambda x: '%.5f' % x)               # customised format for pandas dataframe output


import warnings
warnings.filterwarnings('ignore')                                        # To supress warnings

from sklearn.linear_model import LogisticRegression                       # For training our Logistic Regression model
from sklearn.ensemble import RandomForestClassifier
                                                                          
from sklearn.metrics import confusion_matrix                              # For Performance metrics 
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

from sklearn.model_selection import train_test_split                      # For train test split
from sklearn.metrics import roc_auc_score                                 # For ROC AUC 
from sklearn.metrics import roc_curve                                     # For plotting ROC 
from sklearn.metrics import precision_recall_curve                        # For plotting Precision and Recall 
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Loading Data

# %%
# imporitng data to a pandas dataframe

path1 = r'G:\Downloads\1_Relevel_DS\Data Science Assignment\applicant.csv'
path2 = r'G:\Downloads\1_Relevel_DS\Data Science Assignment\loan.csv'

applicant_data = pd.read_csv(path1)
loan_data = pd.read_csv(path2)

# %%
applicant_data.head()
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  \
# 0       1469590                              67    male
# 1       1203873                              22  female
# 2       1432761                              49    male
# 3       1207582                              45    male
# 4       1674436                              53    male
#
#                Marital_status  Number_of_dependents   Housing  \
# 0                      single                     1       own
# 1  divorced/separated/married                     1       own
# 2                      single                     2       own
# 3                      single                     2  for free
# 4                      single                     2  for free
#
#    Years_at_current_residence            Employment_status  \
# 0                           4  skilled employee / official
# 1                           2  skilled employee / official
# 2                           3         unskilled - resident
# 3                           4  skilled employee / official
# 4                           4  skilled employee / official
#
#   Has_been_employed_for_at_least Has_been_employed_for_at_most  \
# 0                        7 years                           NaN
# 1                         1 year                       4 years
# 2                        4 years                       7 years
# 3                        4 years                       7 years
# 4                         1 year                       4 years
#
#                                Telephone  Foreign_worker  \
# 0  Registered under the applicant's name               1
# 1                                    NaN               1
# 2                                    NaN               1
# 3                                    NaN               1
# 4                                    NaN               1
#
#   Savings_account_balance  \
# 0                     NaN
# 1                     Low
# 2                     Low
# 3                     Low
# 4                     Low
#
#   Balance_in_existing_bank_account_(lower_limit_of_bucket)  \
# 0                                                      NaN
# 1                                                        0
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#   Balance_in_existing_bank_account_(upper_limit_of_bucket)
# 0                                                        0
# 1                                                    2 lac
# 2                                                      NaN
# 3                                                        0
# 4                                                        0

# %%
loan_data.head()
# Out:
#                     loan_application_id  applicant_id  Months_loan_taken_for  \
# 0  d68d975e-edad-11ea-8761-1d6f9c1ff461       1469590                      6
# 1  d68d989e-edad-11ea-b1d5-2bcf65006448       1203873                     48
# 2  d68d995c-edad-11ea-814a-1b6716782575       1432761                     12
# 3  d68d99fc-edad-11ea-8841-17e8848060ae       1207582                     42
# 4  d68d9a92-edad-11ea-9f3d-1f8682db006a       1674436                     24
#
#                 Purpose  Principal_loan_amount  \
# 0  electronic equipment                1169000
# 1  electronic equipment                5951000
# 2             education                2096000
# 3                  FF&E                7882000
# 4           new vehicle                4870000
#
#    EMI_rate_in_percentage_of_disposable_income  \
# 0                                            4
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            3
#
#                                             Property  Has_coapplicant  \
# 0                                        real estate                0
# 1                                        real estate                0
# 2                                        real estate                0
# 3  building society savings agreement/life insurance                0
# 4                                                NaN                0
#
#    Has_guarantor Other_EMI_plans  Number_of_existing_loans_at_this_bank  \
# 0              0             NaN                                      2
# 1              0             NaN                                      1
# 2              0             NaN                                      1
# 3              1             NaN                                      1
# 4              0             NaN                                      2
#
#                              Loan_history  high_risk_applicant
# 0   critical/pending loans at other banks                    0
# 1  existing loans paid back duly till now                    1
# 2   critical/pending loans at other banks                    0
# 3  existing loans paid back duly till now                    0
# 4   delay in paying off loans in the past                    1

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# - 0 = Low credit risk i.e high chance of paying back the loan amount
# - 1 = High credit risk i.e low chance of paying back the loan amount

# %% [markdown]
# 1. applicant_data : This file contains personal data about the (primary) applicant
#
#     - Unique ID: applicant_id (string)
#
#     - Other fields:
#
#         - Primary_applicant_age_in_years (numeric)
#         - Gender (string)
#         - Marital_status (string)
#         - Number_of_dependents (numeric)
#         - Housing (string)
#         - Years_at_current_residence (numeric)
#         - Employment_status (string)
#         - Has_been_employed_for_at_least (string)
#         - Has_been_employed_for_at_most (string)
#         - Telephone (string)
#         - Foreign_worker (numeric)
#         - Savings_account_balance (string)
#         - Balance_in_existing_bank_account_(lower_limit_of_bucket) (string)
#         - Balance_in_existing_bank_account_(upper_limit_of_bucket) (string)

# %% [markdown]
# 2. loan_data : This file contains data more specific to the loan application
#     - Target: high_risk_application (numeric)
#     - Other fields:
#         - applicant_id (string)
#         - Months_loan_taken_for (numeric)
#         - Purpose (string)
#         - Principal_loan_amount (numeric)
#         - EMI_rate_in_percentage_of_disposable_income (numeric)
#         - Property (string)
#         - Has_coapplicant (numeric)
#         - Has_guarantor (numeric)
#         - Other_EMI_plans (string)
#         - Number_of_existing_loans_at_this_bank (numeric)
#         - Loan_history (string)

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# ### applicant_data

# %%
# Checking for missing values
applicant_data .isnull().sum()
# Out:
# applicant_id                                                  0
# Primary_applicant_age_in_years                                0
# Gender                                                        0
# Marital_status                                                0
# Number_of_dependents                                          0
# Housing                                                       0
# Years_at_current_residence                                    0
# Employment_status                                             0
# Has_been_employed_for_at_least                               62
# Has_been_employed_for_at_most                               253
# Telephone                                                   596
# Foreign_worker                                                0
# Savings_account_balance                                     183
# Balance_in_existing_bank_account_(lower_limit_of_bucket)    668
# Balance_in_existing_bank_account_(upper_limit_of_bucket)    457
# dtype: int64

# %% [markdown]
# **Observation:** There are many null values in applicant data. We can check percentage of null value in dataset and delete the columns having more than 45% of null value.
#
# Note: There is no any specific criteria for delete the columns having null values. It's totally depends on business demand.

# %%
100*applicant_data.isnull().sum()/len(applicant_data)
# Out:
# applicant_id                                                0.00000
# Primary_applicant_age_in_years                              0.00000
# Gender                                                      0.00000
# Marital_status                                              0.00000
# Number_of_dependents                                        0.00000
# Housing                                                     0.00000
# Years_at_current_residence                                  0.00000
# Employment_status                                           0.00000
# Has_been_employed_for_at_least                              6.20000
# Has_been_employed_for_at_most                              25.30000
# Telephone                                                  59.60000
# Foreign_worker                                              0.00000
# Savings_account_balance                                    18.30000
# Balance_in_existing_bank_account_(lower_limit_of_bucket)   66.80000
# Balance_in_existing_bank_account_(upper_limit_of_bucket)   45.70000
# dtype: float64

# %%
# deleting columns having >45% null data
null_data = pd.DataFrame({'% of null data':100*applicant_data.isnull().sum()/len(applicant_data)} )
null_data = null_data[null_data['% of null data']<=20]
null_data.index
# Out:
# Index(['applicant_id', 'Primary_applicant_age_in_years', 'Gender',
#        'Marital_status', 'Number_of_dependents', 'Housing',
#        'Years_at_current_residence', 'Employment_status',
#        'Has_been_employed_for_at_least', 'Foreign_worker',
#        'Savings_account_balance'],
#       dtype='object')

# %%
# new applicant data
applicant_data_1 = applicant_data[null_data.index].copy()
applicant_data_1.head()
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  \
# 0       1469590                              67    male
# 1       1203873                              22  female
# 2       1432761                              49    male
# 3       1207582                              45    male
# 4       1674436                              53    male
#
#                Marital_status  Number_of_dependents   Housing  \
# 0                      single                     1       own
# 1  divorced/separated/married                     1       own
# 2                      single                     2       own
# 3                      single                     2  for free
# 4                      single                     2  for free
#
#    Years_at_current_residence            Employment_status  \
# 0                           4  skilled employee / official
# 1                           2  skilled employee / official
# 2                           3         unskilled - resident
# 3                           4  skilled employee / official
# 4                           4  skilled employee / official
#
#   Has_been_employed_for_at_least  Foreign_worker Savings_account_balance
# 0                        7 years               1                     NaN
# 1                         1 year               1                     Low
# 2                        4 years               1                     Low
# 3                        4 years               1                     Low
# 4                         1 year               1                     Low

# %%
# Chaking duplicate values

applicant_data_1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We can see that there is no duplicate data present in applicant data.

# %% [markdown]
# #### Imputing null values

# %%
# let's check data having null values 
null_data[null_data['% of null data']>0]
# Out:
#                                 % of null data
# Has_been_employed_for_at_least         6.20000
# Savings_account_balance               18.30000

# %% [markdown]
# In above table we can see that there is 3 columns having null value. We can impute this null value by taking mode.

# %%
def fill_nan(col):                                                         # function that takes column as parameter
    na_value = applicant_data_1[col].mode()[0]                             # calculating mode of column
    applicant_data_1[col] = applicant_data_1[col].fillna(na_value, axis=0) # impute null value by mode
    return applicant_data_1[col].isnull().sum()                            # returns sum of null value after imputation

# %%
fill_nan('Has_been_employed_for_at_least')
# Out:
# 0

# %%
fill_nan('Savings_account_balance')
# Out:
# 0

# %% [markdown]
# #### Data Cleaning

# %%
applicant_data_1.columns
# Out:
# Index(['applicant_id', 'Primary_applicant_age_in_years', 'Gender',
#        'Marital_status', 'Number_of_dependents', 'Housing',
#        'Years_at_current_residence', 'Employment_status',
#        'Has_been_employed_for_at_least', 'Foreign_worker',
#        'Savings_account_balance'],
#       dtype='object')

# %% [markdown]
# ##### 'Marital_status' Column

# %%
l = []                                                              # creating empty list
for i in applicant_data_1['Marital_status']:
    if i == 'divorced/separated/married':                           
        l.append('separated')
    elif i == 'divorced/separated':
        l.append('separated')
    elif i == 'married/widowed':
        l.append('married')
    else:
        l.append(i) 
l[:5]
# Out:
# ['single', 'separated', 'single', 'single', 'single']

# %%
applicant_data_1['Marital_status'] = l                       # update old Marital_status with new values store in list l

# %% [markdown]
# ##### "Housing" Column

# %%
applicant_data_1['Housing'].unique()                         # check unique value present in a column
# Out:
# array(['own', 'for free', 'rent'], dtype=object)

# %%
applicant_data_1['Housing'] = applicant_data_1['Housing'].apply(
    lambda x: x.replace('for free', 'free'))             
                                                           # apply lambda function to replace 'for free' by 'free'

applicant_data_1['Housing'].unique()                       # check unique value present in a column after cleaning
# Out:
# array(['own', 'free', 'rent'], dtype=object)

# %% [markdown]
# ##### "Employment_status" column

# %%
applicant_data_1['Employment_status'].unique()
# Out:
# array(['skilled employee / official', 'unskilled - resident',
#        'management / self-employed / highly qualified employee / officer',
#        'unemployed / unskilled - non-resident'], dtype=object)

# %%
x = []
for i in applicant_data_1['Employment_status']:
    if i =='skilled employee / official':
        x.append('employee')
    elif i == 'management / self-employed / highly qualified employee / officer':
        x.append('qualified employee')
    elif i == 'unemployed / unskilled - non-resident':
        x.append('unemployed')
    else:
        x.append(i)
applicant_data_1['Employment_status'] = x
applicant_data_1['Employment_status'].unique()
# Out:
# array(['employee', 'unskilled - resident', 'qualified employee',
#        'unemployed'], dtype=object)

# %% [markdown]
# ##### "Has_been_employed_for_at_least" column

# %%
applicant_data_1['Has_been_employed_for_at_least'].unique()
# Out:
# array(['7 years', '1 year', '4 years', '0 year'], dtype=object)

# %%
applicant_data_1['Has_been_employed_for_at_least (year)'] = applicant_data_1[
    'Has_been_employed_for_at_least'].apply(
        lambda x: x.strip(' years') or x.strip(' year'))                         # remove year or years from the data 
          
applicant_data_1['Has_been_employed_for_at_least (year)'].unique()
# Out:
# array(['7', '1', '4', '0'], dtype=object)

# %%
# Convert data type in int64
applicant_data_1['Has_been_employed_for_at_least (year)'] = applicant_data_1[
    'Has_been_employed_for_at_least (year)'].astype(int)

type(applicant_data_1['Has_been_employed_for_at_least (year)'][0])              # check data type of data
# Out:
# numpy.int32

# %%
applicant_data_1.drop(['Has_been_employed_for_at_least'], axis=1,inplace=True )

# %%
# final data looks loke

applicant_data_1.sample(10)
# Out:
#      applicant_id  Primary_applicant_age_in_years  Gender Marital_status  \
# 715       1314021                              63    male         single
# 268       1310758                              45    male      separated
# 901       1621154                              44    male      separated
# 793       1414229                              51    male      separated
# 214       1529476                              51    male         single
# 727       1695402                              25  female      separated
# 690       1345875                              25    male      separated
# 810       1109861                              26    male        married
# 717       1849511                              32    male         single
# 970       1662480                              22    male         single
#
#      Number_of_dependents Housing  Years_at_current_residence  \
# 715                     1     own                           4
# 268                     1     own                           4
# 901                     1     own                           4
# 793                     1    free                           4
# 214                     1     own                           2
# 727                     1    rent                           4
# 690                     1     own                           3
# 810                     1     own                           2
# 717                     1    free                           2
# 970                     1     own                           2
#
#       Employment_status  Foreign_worker Savings_account_balance  \
# 715            employee               1                     Low
# 268  qualified employee               0                     Low
# 901            employee               1                     Low
# 793            employee               1                     Low
# 214            employee               1                     Low
# 727            employee               1                     Low
# 690            employee               1                     Low
# 810            employee               1                     Low
# 717  qualified employee               1                     Low
# 970            employee               1                  Medium
#
#      Has_been_employed_for_at_least (year)
# 715                                      7
# 268                                      7
# 901                                      0
# 793                                      7
# 214                                      7
# 727                                      1
# 690                                      1
# 810                                      0
# 717                                      1
# 970                                      1

# %%
applicant_data_1.shape
# Out:
# (1000, 11)

# %%
applicant_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   applicant_id                           1000 non-null   int64
#  1   Primary_applicant_age_in_years         1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Marital_status                         1000 non-null   object
#  4   Number_of_dependents                   1000 non-null   int64
#  5   Housing                                1000 non-null   object
#  6   Years_at_current_residence             1000 non-null   int64
#  7   Employment_status                      1000 non-null   object
#  8   Foreign_worker                         1000 non-null   int64
#  9   Savings_account_balance                1000 non-null   object
#  10  Has_been_employed_for_at_least (year)  1000 non-null   int32
# dtypes: int32(1), int64(5), object(5)
# memory usage: 82.2+ KB

# %% [markdown]
# <center>=//=

# %% [markdown]
# ### loan_data:

# %%
loan_data.sample(20)
# Out:
#                       loan_application_id  applicant_id  \
# 851  d68f7236-edad-11ea-8fe0-5087c4a61be6       1785162
# 759  d68f3c80-edad-11ea-ac64-5a2530ff8e11       1239673
# 877  d68f7f74-edad-11ea-aa5f-477c81b7c402       1624943
# 96   d68dcbfc-edad-11ea-ad44-06ed8ffa90db       1610826
# 798  d68f55d0-edad-11ea-84a8-2800d7327005       1258889
# 660  d68f07ec-edad-11ea-b6db-3496b8dbd5c8       1352279
# 756  d68f3ae6-edad-11ea-98f0-22b178508d26       1868234
# 653  d68f042c-edad-11ea-b98f-12dc3733eac6       1476071
# 217  d68e0c66-edad-11ea-b0b3-1fa0e1d66548       1698484
# 101  d68dcea4-edad-11ea-bb1a-384a200d31e4       1466716
# 244  d68e1ac6-edad-11ea-8f68-351b995233b8       1591456
# 84   d68dc580-edad-11ea-82fe-49573323bbb2       1238277
# 841  d68f6d18-edad-11ea-8c6f-363548887791       1313830
# 876  d68f7ef2-edad-11ea-92f3-2d94a292ed64       1860396
# 842  d68f6d9a-edad-11ea-96c3-3bdfc5f969e6       1731499
# 738  d68f310e-edad-11ea-a518-3e596ace1832       1165210
# 670  d68f0d46-edad-11ea-8e2a-423866800420       1844813
# 809  d68f5bac-edad-11ea-8c61-331ac341d459       1366939
# 376  d68e6cec-edad-11ea-a34d-01b2c2564b41       1711334
# 24   d68da55a-edad-11ea-9086-556c75abdef8       1847764
#
#      Months_loan_taken_for               Purpose  Principal_loan_amount  \
# 851                     24          used vehicle                4042000
# 759                     12           new vehicle                 691000
# 877                     36  electronic equipment                3595000
# 96                      12             education                2012000
# 798                     24           new vehicle                 717000
# 660                     12  electronic equipment                1297000
# 756                      6           new vehicle                1299000
# 653                     36           new vehicle                8086000
# 217                     36  electronic equipment                3913000
# 101                     36  electronic equipment                2323000
# 244                     12    career development                3447000
# 84                      10  electronic equipment                2315000
# 841                     21          used vehicle                2993000
# 876                     18  electronic equipment                1940000
# 842                     18          repair costs                1943000
# 738                      6           new vehicle                6761000
# 670                     24              business                4139000
# 809                     15           new vehicle                1778000
# 376                     18  electronic equipment                2320000
# 24                      10                  FF&E                2069000
#
#      EMI_rate_in_percentage_of_disposable_income  \
# 851                                            3
# 759                                            4
# 877                                            4
# 96                                             4
# 798                                            4
# 660                                            3
# 756                                            1
# 653                                            2
# 217                                            2
# 101                                            4
# 244                                            4
# 84                                             3
# 841                                            3
# 876                                            3
# 842                                            4
# 738                                            1
# 670                                            3
# 809                                            2
# 376                                            2
# 24                                             2
#
#                                               Property  Has_coapplicant  \
# 851  building society savings agreement/life insurance                0
# 759  building society savings agreement/life insurance                0
# 877                                       car or other                0
# 96                                        car or other                0
# 798                                       car or other                0
# 660                                        real estate                0
# 756                                        real estate                0
# 653                                       car or other                0
# 217                                        real estate                0
# 101                                       car or other                0
# 244                                        real estate                0
# 84                                         real estate                0
# 841                                        real estate                0
# 876                                                NaN                1
# 842                                        real estate                0
# 738                                                NaN                0
# 670  building society savings agreement/life insurance                0
# 809                                        real estate                0
# 376                                        real estate                0
# 24                                        car or other                0
#
#      Has_guarantor Other_EMI_plans  Number_of_existing_loans_at_this_bank  \
# 851              0             NaN                                      2
# 759              0             NaN                                      2
# 877              0             NaN                                      1
# 96               0             NaN                                      1
# 798              0             NaN                                      2
# 660              0             NaN                                      1
# 756              0             NaN                                      3
# 653              0             NaN                                      4
# 217              0             NaN                                      1
# 101              0             NaN                                      1
# 244              0             NaN                                      1
# 84               0             NaN                                      1
# 841              0          stores                                      2
# 876              0            bank                                      1
# 842              0             NaN                                      1
# 738              0             NaN                                      2
# 670              0             NaN                                      2
# 809              0             NaN                                      2
# 376              0             NaN                                      2
# 24               0             NaN                                      2
#
#                                 Loan_history  high_risk_applicant
# 851    critical/pending loans at other banks                    0
# 759    critical/pending loans at other banks                    1
# 877   existing loans paid back duly till now                    0
# 96     critical/pending loans at other banks                    0
# 798    delay in paying off loans in the past                    0
# 660   existing loans paid back duly till now                    0
# 756    critical/pending loans at other banks                    0
# 653    delay in paying off loans in the past                    1
# 217   existing loans paid back duly till now                    0
# 101   existing loans paid back duly till now                    0
# 244    all loans at this bank paid back duly                    0
# 84    existing loans paid back duly till now                    0
# 841    delay in paying off loans in the past                    0
# 876    all loans at this bank paid back duly                    0
# 842   existing loans paid back duly till now                    1
# 738    critical/pending loans at other banks                    0
# 670    critical/pending loans at other banks                    0
# 809  no loans taken/all loans paid back duly                    1
# 376    delay in paying off loans in the past                    0
# 24     critical/pending loans at other banks                    0

# %% [markdown]
# #### Imputing Null Value

# %%
loan_data.shape
# Out:
# (1000, 13)

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   loan_application_id                          1000 non-null   object
#  1   applicant_id                                 1000 non-null   int64
#  2   Months_loan_taken_for                        1000 non-null   int64
#  3   Purpose                                      988 non-null    object
#  4   Principal_loan_amount                        1000 non-null   int64
#  5   EMI_rate_in_percentage_of_disposable_income  1000 non-null   int64
#  6   Property                                     846 non-null    object
#  7   Has_coapplicant                              1000 non-null   int64
#  8   Has_guarantor                                1000 non-null   int64
#  9   Other_EMI_plans                              186 non-null    object
#  10  Number_of_existing_loans_at_this_bank        1000 non-null   int64
#  11  Loan_history                                 1000 non-null   object
#  12  high_risk_applicant                          1000 non-null   int64
# dtypes: int64(8), object(5)
# memory usage: 101.7+ KB

# %%
100 * loan_data.isnull().sum()/len(loan_data)
# Out:
# loan_application_id                            0.00000
# applicant_id                                   0.00000
# Months_loan_taken_for                          0.00000
# Purpose                                        1.20000
# Principal_loan_amount                          0.00000
# EMI_rate_in_percentage_of_disposable_income    0.00000
# Property                                      15.40000
# Has_coapplicant                                0.00000
# Has_guarantor                                  0.00000
# Other_EMI_plans                               81.40000
# Number_of_existing_loans_at_this_bank          0.00000
# Loan_history                                   0.00000
# high_risk_applicant                            0.00000
# dtype: float64

# %%
loan_data.drop('Other_EMI_plans', axis=1, inplace=True)          # Other_EMI_plans has more than 80% null data. droping it.

# %%
loan_data.isnull().sum()
# Out:
# loan_application_id                              0
# applicant_id                                     0
# Months_loan_taken_for                            0
# Purpose                                         12
# Principal_loan_amount                            0
# EMI_rate_in_percentage_of_disposable_income      0
# Property                                       154
# Has_coapplicant                                  0
# Has_guarantor                                    0
# Number_of_existing_loans_at_this_bank            0
# Loan_history                                     0
# high_risk_applicant                              0
# dtype: int64

# %%
loan_data['Purpose'].mode()
# Out:
# 0    electronic equipment
# Name: Purpose, dtype: object

# %%
loan_data['Property'].mode()
# Out:
# 0    car or other
# Name: Property, dtype: object

# %%
def fill_nan(col):                                                         # function that takes column as parameter
    na_value = loan_data[col].mode()[0]                                    # calculating mode of column
    loan_data[col] = loan_data[col].fillna(na_value, axis=0)               # impute null value by mode
    return loan_data[col].isnull().sum()                                   # returns sum of null value after imputation

# %%
fill_nan('Purpose')
# Out:
# 0

# %%
fill_nan('Property')
# Out:
# 0

# %%
loan_data.isnull().sum()
# Out:
# loan_application_id                            0
# applicant_id                                   0
# Months_loan_taken_for                          0
# Purpose                                        0
# Principal_loan_amount                          0
# EMI_rate_in_percentage_of_disposable_income    0
# Property                                       0
# Has_coapplicant                                0
# Has_guarantor                                  0
# Number_of_existing_loans_at_this_bank          0
# Loan_history                                   0
# high_risk_applicant                            0
# dtype: int64

# %%
loan_data.columns
# Out:
# Index(['loan_application_id', 'applicant_id', 'Months_loan_taken_for',
#        'Purpose', 'Principal_loan_amount',
#        'EMI_rate_in_percentage_of_disposable_income', 'Property',
#        'Has_coapplicant', 'Has_guarantor',
#        'Number_of_existing_loans_at_this_bank', 'Loan_history',
#        'high_risk_applicant'],
#       dtype='object')

# %%
loan_data['Loan_history'].value_counts()
# Out:
# existing loans paid back duly till now     530
# critical/pending loans at other banks      293
# delay in paying off loans in the past       88
# all loans at this bank paid back duly       49
# no loans taken/all loans paid back duly     40
# Name: Loan_history, dtype: int64

# %%
df = applicant_data_1.merge(loan_data,on = 'applicant_id')          # final data
df.sample(10)
# Out:
#      applicant_id  Primary_applicant_age_in_years  Gender Marital_status  \
# 148       1901178                              28    male         single
# 294       1563134                              46    male      separated
# 781       1129775                              60    male         single
# 893       1851827                              34    male         single
# 131       1817517                              29    male         single
# 930       1629759                              24    male         single
# 755       1621486                              32  female      separated
# 209       1241829                              55    male         single
# 568       1754897                              41    male         single
# 791       1372040                              41    male         single
#
#      Number_of_dependents Housing  Years_at_current_residence  \
# 148                     1     own                           2
# 294                     2     own                           2
# 781                     1     own                           4
# 893                     1     own                           4
# 131                     1     own                           3
# 930                     1     own                           1
# 755                     1    rent                           4
# 209                     1     own                           2
# 568                     2     own                           1
# 791                     2     own                           4
#
#         Employment_status  Foreign_worker Savings_account_balance  ...  \
# 148              employee               1                     Low  ...
# 294    qualified employee               1                     Low  ...
# 781              employee               1               Very high  ...
# 893              employee               1                     Low  ...
# 131              employee               1                     Low  ...
# 930  unskilled - resident               0                     Low  ...
# 755              employee               1                     Low  ...
# 209              employee               0               Very high  ...
# 568              employee               1                     Low  ...
# 791    qualified employee               1                     Low  ...
#
#      Months_loan_taken_for               Purpose  Principal_loan_amount  \
# 148                     36                  FF&E                5371000
# 294                     48              business                7629000
# 781                     24           new vehicle                1940000
# 893                     36          used vehicle                5800000
# 131                     36             education                6887000
# 930                     24                  FF&E                1747000
# 755                     24           new vehicle                1285000
# 209                     12          used vehicle                1413000
# 568                     48  electronic equipment                3979000
# 791                     24          used vehicle                6313000
#
#     EMI_rate_in_percentage_of_disposable_income  \
# 148                                           3
# 294                                           4
# 781                                           4
# 893                                           3
# 131                                           4
# 930                                           4
# 755                                           4
# 209                                           3
# 568                                           4
# 791                                           3
#
#                                               Property  Has_coapplicant  \
# 148  building society savings agreement/life insurance                0
# 294                                       car or other                0
# 781                                        real estate                0
# 893                                       car or other                0
# 131  building society savings agreement/life insurance                0
# 930  building society savings agreement/life insurance                1
# 755                                       car or other                0
# 209  building society savings agreement/life insurance                0
# 568                                       car or other                0
# 791                                       car or other                0
#
#     Has_guarantor  Number_of_existing_loans_at_this_bank  \
# 148             1                                      2
# 294             0                                      2
# 781             0                                      1
# 893             0                                      2
# 131             0                                      1
# 930             0                                      1
# 755             0                                      1
# 209             0                                      1
# 568             0                                      2
# 791             0                                      1
#
#                                Loan_history  high_risk_applicant
# 148   critical/pending loans at other banks                    0
# 294   critical/pending loans at other banks                    0
# 781   critical/pending loans at other banks                    0
# 893   critical/pending loans at other banks                    0
# 131   delay in paying off loans in the past                    1
# 930  existing loans paid back duly till now                    0
# 755  existing loans paid back duly till now                    1
# 209  existing loans paid back duly till now                    0
# 568  existing loans paid back duly till now                    0
# 791  existing loans paid back duly till now                    0
#
# [10 rows x 22 columns]

# %%
df.shape
# Out:
# (1000, 22)

# %%
df.columns
# Out:
# Index(['applicant_id', 'Primary_applicant_age_in_years', 'Gender',
#        'Marital_status', 'Number_of_dependents', 'Housing',
#        'Years_at_current_residence', 'Employment_status', 'Foreign_worker',
#        'Savings_account_balance', 'Has_been_employed_for_at_least (year)',
#        'loan_application_id', 'Months_loan_taken_for', 'Purpose',
#        'Principal_loan_amount', 'EMI_rate_in_percentage_of_disposable_income',
#        'Property', 'Has_coapplicant', 'Has_guarantor',
#        'Number_of_existing_loans_at_this_bank', 'Loan_history',
#        'high_risk_applicant'],
#       dtype='object')

# %%
df.drop(['applicant_id','loan_application_id'], axis=1, inplace=True)

# %%
df.describe().transpose()
# Out:
#                                                  count          mean  \
# Primary_applicant_age_in_years              1000.00000      35.54600
# Number_of_dependents                        1000.00000       1.15500
# Years_at_current_residence                  1000.00000       2.84500
# Foreign_worker                              1000.00000       0.96300
# Has_been_employed_for_at_least (year)       1000.00000       2.86800
# Months_loan_taken_for                       1000.00000      20.90300
# Principal_loan_amount                       1000.00000 3271258.00000
# EMI_rate_in_percentage_of_disposable_income 1000.00000       2.97300
# Has_coapplicant                             1000.00000       0.04100
# Has_guarantor                               1000.00000       0.05200
# Number_of_existing_loans_at_this_bank       1000.00000       1.40700
# high_risk_applicant                         1000.00000       0.30000
#
#                                                       std          min  \
# Primary_applicant_age_in_years                   11.37547     19.00000
# Number_of_dependents                              0.36209      1.00000
# Years_at_current_residence                        1.10372      1.00000
# Foreign_worker                                    0.18886      0.00000
# Has_been_employed_for_at_least (year)             2.71366      0.00000
# Months_loan_taken_for                            12.05881      4.00000
# Principal_loan_amount                       2822736.87596 250000.00000
# EMI_rate_in_percentage_of_disposable_income       1.11871      1.00000
# Has_coapplicant                                   0.19839      0.00000
# Has_guarantor                                     0.22214      0.00000
# Number_of_existing_loans_at_this_bank             0.57765      1.00000
# high_risk_applicant                               0.45849      0.00000
#
#                                                       25%           50%  \
# Primary_applicant_age_in_years                   27.00000      33.00000
# Number_of_dependents                              1.00000       1.00000
# Years_at_current_residence                        2.00000       3.00000
# Foreign_worker                                    1.00000       1.00000
# Has_been_employed_for_at_least (year)             1.00000       1.00000
# Months_loan_taken_for                            12.00000      18.00000
# Principal_loan_amount                       1365500.00000 2319500.00000
# EMI_rate_in_percentage_of_disposable_income       2.00000       3.00000
# Has_coapplicant                                   0.00000       0.00000
# Has_guarantor                                     0.00000       0.00000
# Number_of_existing_loans_at_this_bank             1.00000       1.00000
# high_risk_applicant                               0.00000       0.00000
#
#                                                       75%            max
# Primary_applicant_age_in_years                   42.00000       75.00000
# Number_of_dependents                              1.00000        2.00000
# Years_at_current_residence                        4.00000        4.00000
# Foreign_worker                                    1.00000        1.00000
# Has_been_employed_for_at_least (year)             7.00000        7.00000
# Months_loan_taken_for                            24.00000       72.00000
# Principal_loan_amount                       3972250.00000 18424000.00000
# EMI_rate_in_percentage_of_disposable_income       4.00000        4.00000
# Has_coapplicant                                   0.00000        1.00000
# Has_guarantor                                     0.00000        1.00000
# Number_of_existing_loans_at_this_bank             2.00000        4.00000
# high_risk_applicant                               1.00000        1.00000

# %% [markdown]
# ## <center> Feature Engineering

# %% [markdown]
# ### Feature Engineering | Dropping Unnecessary or duplicate features and deleting Outliers

# %%
# Checking the features available in our data before dropping
df1 = df.copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Primary_applicant_age_in_years               1000 non-null   int64
#  1   Gender                                       1000 non-null   object
#  2   Marital_status                               1000 non-null   object
#  3   Number_of_dependents                         1000 non-null   int64
#  4   Housing                                      1000 non-null   object
#  5   Years_at_current_residence                   1000 non-null   int64
#  6   Employment_status                            1000 non-null   object
#  7   Foreign_worker                               1000 non-null   int64
#  8   Savings_account_balance                      1000 non-null   object
#  9   Has_been_employed_for_at_least (year)        1000 non-null   int32
#  10  Months_loan_taken_for                        1000 non-null   int64
#  11  Purpose                                      1000 non-null   object
#  12  Principal_loan_amount                        1000 non-null   int64
#  13  EMI_rate_in_percentage_of_disposable_income  1000 non-null   int64
#  14  Property                                     1000 non-null   object
#  15  Has_coapplicant                              1000 non-null   int64
#  16  Has_guarantor                                1000 non-null   int64
#  17  Number_of_existing_loans_at_this_bank        1000 non-null   int64
#  18  Loan_history                                 1000 non-null   object
#  19  high_risk_applicant                          1000 non-null   int64
# dtypes: int32(1), int64(11), object(8)
# memory usage: 160.2+ KB

# %%
# As per EDA, dropping columns which are either correlated with some feature or are duplicates.
clm_to_drop = ['Principal_loan_amount','Months_loan_taken_for','Primary_applicant_age_in_years']
df1.drop(clm_to_drop, axis=1, inplace=True)

# %%
df1.sample(20)
# Out:
#      Gender Marital_status  Number_of_dependents Housing  \
# 53     male         single                     1     own
# 35     male         single                     1     own
# 31     male         single                     1     own
# 786    male         single                     1     own
# 177    male         single                     1     own
# 658  female      separated                     1     own
# 957    male         single                     1     own
# 542    male         single                     1     own
# 94     male         single                     1     own
# 323    male         single                     1     own
# 641    male         single                     1     own
# 58   female      separated                     1     own
# 88     male         single                     2     own
# 666    male         single                     2     own
# 29     male         single                     1     own
# 106    male         single                     2     own
# 759    male         single                     1     own
# 628    male         single                     1     own
# 699    male         single                     1    rent
# 906    male         single                     1     own
#
#      Years_at_current_residence     Employment_status  Foreign_worker  \
# 53                            1              employee               1
# 35                            2  unskilled - resident               1
# 31                            2              employee               1
# 786                           4              employee               1
# 177                           4              employee               1
# 658                           1              employee               1
# 957                           4  unskilled - resident               1
# 542                           4              employee               1
# 94                            4              employee               1
# 323                           2              employee               1
# 641                           4  unskilled - resident               1
# 58                            2    qualified employee               1
# 88                            3    qualified employee               1
# 666                           2              employee               1
# 29                            4              employee               1
# 106                           4    qualified employee               1
# 759                           3              employee               1
# 628                           4              employee               1
# 699                           4    qualified employee               1
# 906                           2  unskilled - resident               0
#
#     Savings_account_balance  Has_been_employed_for_at_least (year)  \
# 53                      Low                                      1
# 35                      Low                                      0
# 31                      Low                                      1
# 786                    High                                      7
# 177                    High                                      7
# 658                     Low                                      1
# 957                     Low                                      7
# 542                     Low                                      7
# 94                Very high                                      7
# 323               Very high                                      1
# 641                     Low                                      7
# 58                      Low                                      7
# 88                   Medium                                      4
# 666               Very high                                      1
# 29                      Low                                      7
# 106                     Low                                      7
# 759                     Low                                      7
# 628                    High                                      1
# 699                     Low                                      7
# 906                     Low                                      4
#
#                   Purpose  EMI_rate_in_percentage_of_disposable_income  \
# 53           used vehicle                                            2
# 35   electronic equipment                                            4
# 31                   FF&E                                            2
# 786  electronic equipment                                            3
# 177  electronic equipment                                            4
# 658              business                                            2
# 957  electronic equipment                                            2
# 542                  FF&E                                            4
# 94            new vehicle                                            4
# 323                  FF&E                                            4
# 641          repair costs                                            4
# 58            new vehicle                                            3
# 88            new vehicle                                            4
# 666                  FF&E                                            4
# 29               business                                            3
# 106           new vehicle                                            2
# 759           new vehicle                                            4
# 628                  FF&E                                            4
# 699             education                                            4
# 906           new vehicle                                            2
#
#                                               Property  Has_coapplicant  \
# 53   building society savings agreement/life insurance                0
# 35   building society savings agreement/life insurance                0
# 31                                        car or other                0
# 786                                       car or other                0
# 177                                       car or other                0
# 658                                       car or other                0
# 957                                        real estate                0
# 542  building society savings agreement/life insurance                0
# 94                                         real estate                0
# 323                                       car or other                0
# 641                                       car or other                0
# 58                                        car or other                0
# 88                                        car or other                0
# 666                                       car or other                0
# 29                                        car or other                0
# 106                                       car or other                0
# 759  building society savings agreement/life insurance                0
# 628                                        real estate                0
# 699                                       car or other                0
# 906                                        real estate                1
#
#      Has_guarantor  Number_of_existing_loans_at_this_bank  \
# 53               0                                      1
# 35               0                                      2
# 31               0                                      1
# 786              0                                      1
# 177              0                                      2
# 658              0                                      2
# 957              0                                      3
# 542              0                                      1
# 94               0                                      1
# 323              0                                      1
# 641              0                                      2
# 58               0                                      1
# 88               0                                      1
# 666              0                                      1
# 29               0                                      2
# 106              0                                      2
# 759              0                                      2
# 628              0                                      2
# 699              0                                      1
# 906              0                                      1
#
#                                 Loan_history  high_risk_applicant
# 53    existing loans paid back duly till now                    0
# 35     critical/pending loans at other banks                    1
# 31    existing loans paid back duly till now                    0
# 786   existing loans paid back duly till now                    0
# 177    critical/pending loans at other banks                    0
# 658  no loans taken/all loans paid back duly                    0
# 957    critical/pending loans at other banks                    0
# 542   existing loans paid back duly till now                    1
# 94    existing loans paid back duly till now                    0
# 323   existing loans paid back duly till now                    0
# 641   existing loans paid back duly till now                    0
# 58    existing loans paid back duly till now                    0
# 88    existing loans paid back duly till now                    0
# 666    all loans at this bank paid back duly                    0
# 29     delay in paying off loans in the past                    1
# 106    all loans at this bank paid back duly                    1
# 759    critical/pending loans at other banks                    1
# 628    critical/pending loans at other banks                    0
# 699   existing loans paid back duly till now                    0
# 906   existing loans paid back duly till now                    0

# %% [markdown]
# ### Feature Engineering | Creating dummies

# %%
df1.columns
# Out:
# Index(['Gender', 'Marital_status', 'Number_of_dependents', 'Housing',
#        'Years_at_current_residence', 'Employment_status', 'Foreign_worker',
#        'Savings_account_balance', 'Has_been_employed_for_at_least (year)',
#        'Purpose', 'EMI_rate_in_percentage_of_disposable_income', 'Property',
#        'Has_coapplicant', 'Has_guarantor',
#        'Number_of_existing_loans_at_this_bank', 'Loan_history',
#        'high_risk_applicant'],
#       dtype='object')

# %%
df1['Loan_history'].unique()
# Out:
# array(['critical/pending loans at other banks',
#        'existing loans paid back duly till now',
#        'delay in paying off loans in the past',
#        'no loans taken/all loans paid back duly',
#        'all loans at this bank paid back duly'], dtype=object)

# %%
# Dropping target to create Features set an Target set seperately as X & Y
X = df1.drop(['high_risk_applicant'], axis=1)
Y = df1['high_risk_applicant']

# %%
X.select_dtypes(include='object').columns
# Out:
# Index(['Gender', 'Marital_status', 'Housing', 'Employment_status',
#        'Savings_account_balance', 'Purpose', 'Property', 'Loan_history'],
#       dtype='object')

# %%
labelencoder_X = LabelEncoder()
for i in (X.select_dtypes(include='object').columns):
    X[i] = labelencoder_X.fit_transform(X[i])

# %%
X.head(10)
# Out:
#    Gender  Marital_status  Number_of_dependents  Housing  \
# 0       1               2                     1        1
# 1       0               1                     1        1
# 2       1               2                     2        1
# 3       1               2                     2        0
# 4       1               2                     2        0
# 5       1               2                     2        0
# 6       1               2                     1        1
# 7       1               2                     1        2
# 8       1               1                     1        1
# 9       1               0                     1        1
#
#    Years_at_current_residence  Employment_status  Foreign_worker  \
# 0                           4                  0               1
# 1                           2                  0               1
# 2                           3                  3               1
# 3                           4                  0               1
# 4                           4                  0               1
# 5                           4                  3               1
# 6                           4                  0               1
# 7                           2                  1               1
# 8                           4                  3               1
# 9                           2                  1               1
#
#    Savings_account_balance  Has_been_employed_for_at_least (year)  Purpose  \
# 0                        1                                      7        5
# 1                        1                                      1        5
# 2                        1                                      4        4
# 3                        1                                      4        0
# 4                        1                                      1        6
# 5                        1                                      1        4
# 6                        0                                      7        0
# 7                        1                                      1        8
# 8                        3                                      4        5
# 9                        1                                      1        6
#
#    EMI_rate_in_percentage_of_disposable_income  Property  Has_coapplicant  \
# 0                                            4         2                0
# 1                                            2         2                0
# 2                                            2         2                0
# 3                                            2         0                0
# 4                                            3         1                0
# 5                                            2         1                0
# 6                                            3         0                0
# 7                                            2         1                0
# 8                                            2         2                0
# 9                                            4         1                0
#
#    Has_guarantor  Number_of_existing_loans_at_this_bank  Loan_history
# 0              0                                      2             1
# 1              0                                      1             3
# 2              0                                      1             1
# 3              1                                      1             3
# 4              0                                      2             2
# 5              0                                      1             3
# 6              0                                      1             3
# 7              0                                      1             3
# 8              0                                      1             3
# 9              0                                      2             1

# %%
X.shape
# Out:
# (1000, 16)

# %% [markdown]
# ###  Feature Engineering | Train Test Split

# %%
# Train tst split

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.20, random_state = 1,stratify=Y)

# %% [markdown]
# ## <center>  Logistic Regression

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, classification_report

m1 = 'LogisticRegression'

lr = LogisticRegression(random_state=1, max_iter=1000)

model = lr.fit(X_train, y_train)
lr_predict = lr.predict(X_test)

lr_conf_matrix = confusion_matrix(y_test, lr_predict)
lr_acc_score = accuracy_score(y_test, lr_predict)

print("confussion matrix")
print(lr_conf_matrix)
print("\n")
print("Accuracy of Logistic Regression:",lr_acc_score*100,'\n')
print(classification_report(y_test,lr_predict))
# Out:
# confussion matrix
# [[134   6]
#  [ 57   3]]
#
#
# Accuracy of Logistic Regression: 68.5
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.96      0.81       140
#            1       0.33      0.05      0.09        60
#
#     accuracy                           0.69       200
#    macro avg       0.52      0.50      0.45       200
# weighted avg       0.59      0.69      0.59       200

# %% [markdown]
# ## <center>Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
print('Random Forest Classfier')

rf_model = RandomForestClassifier(n_estimators=150, random_state=0,max_depth=8, 
                            n_jobs=-1, max_features=10)
rf_model.fit(X_train,y_train)

rf_predicted = rf_model.predict(X_test)
rf_conf_matrix = confusion_matrix(y_test, rf_predicted,labels=(1,0))
rf_acc_score = accuracy_score(y_test, rf_predicted)

print("confussion matrix")
print(rf_conf_matrix)
print("\n")
print("Accuracy of Random Forest:",rf_acc_score*100,'\n')
print(classification_report(y_test,rf_predicted))
# Out:
# Random Forest Classfier
# confussion matrix
# [[ 15  45]
#  [  9 131]]
#
#
# Accuracy of Random Forest: 73.0
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.94      0.83       140
#            1       0.62      0.25      0.36        60
#
#     accuracy                           0.73       200
#    macro avg       0.68      0.59      0.59       200
# weighted avg       0.71      0.73      0.69       200

# %%
rf_model.feature_importances_
# Out:
# array([0.03416757, 0.05247769, 0.02911435, 0.04680883, 0.07133124,
#        0.0631739 , 0.01132881, 0.06374291, 0.09557558, 0.13169478,
#        0.0827777 , 0.06584328, 0.03251147, 0.0239286 , 0.04378322,
#        0.15174006])

# %%
Feature= pd.DataFrame({'Feature':X_train.columns,'Importance':rf_model.feature_importances_})
Feature.sort_values('Importance',ascending=False,inplace=True)
Feature.set_index('Feature',inplace=True)
Feature.head(10)
# Out:
#                                              Importance
# Feature
# Loan_history                                    0.15174
# Purpose                                         0.13169
# Has_been_employed_for_at_least (year)           0.09558
# EMI_rate_in_percentage_of_disposable_income     0.08278
# Years_at_current_residence                      0.07133
# Property                                        0.06584
# Savings_account_balance                         0.06374
# Employment_status                               0.06317
# Marital_status                                  0.05248
# Housing                                         0.04681

# %%
# exporting Random Forest for new data prediction 
import pickle
pickle.dump(rf_model,open('rf_model.pkl','wb'))

# %%
# Thank You
